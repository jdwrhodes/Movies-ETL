# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv('./Resources/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection budget  \
# 13928  False                   NaN      0
# 8292   False                   NaN      0
# 22756  False                   NaN      0
# 44644  False                   NaN      0
# 27038  False                   NaN      0
#
#                                                   genres  \
# 13928                     [{'id': 35, 'name': 'Comedy'}]
# 8292                 [{'id': 99, 'name': 'Documentary'}]
# 22756  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 44644                      [{'id': 18, 'name': 'Drama'}]
# 27038                      [{'id': 18, 'name': 'Drama'}]
#
#                                             homepage      id    imdb_id  \
# 13928                                            NaN   20382  tt0833557
# 8292                                             NaN  210864  tt0424885
# 22756                                            NaN   52147  tt0981352
# 44644                                            NaN   27221  tt0088412
# 27038  http://www.sonypictures.com/movies/squatters/  268321  tt2359307
#
#       original_language                                     original_title  \
# 13928                en                                         Visioneers
# 8292                 en  Celsius 41.11: The Temperature at Which the Br...
# 22756                tr                                               Ulak
# 44644                de                      Wo die grünen Ameisen träumen
# 27038                en                                          Squatters
#
#                                                 overview  ... release_date  \
# 13928  Visioneer George Washington Winsterhammerman l...  ...   2008-06-12
# 8292   This film attempts to correct the record when ...  ...   2004-10-22
# 22756                                                NaN  ...   2008-02-25
# 44644  Extraordinary images from Werner Herzog. Shot ...  ...   1984-08-31
# 27038  A wealthy couple from the Pacific Palisades di...  ...   2014-05-14
#
#       revenue runtime                          spoken_languages    status  \
# 13928     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8292      0.0    72.0                                        []  Released
# 22756     0.0     0.0   [{'iso_639_1': 'tr', 'name': 'Türkçe'}]  Released
# 44644     0.0   100.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 27038     0.0   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                             tagline  \
# 13928                                           NaN
# 8292   The truth behind the lies of Fahrenheit 9/11
# 22756                                           NaN
# 44644                                           NaN
# 27038                     They want what they have.
#
#                                                    title  video vote_average  \
# 13928                                         Visioneers  False          6.0
# 8292   Celsius 41.11: The Temperature at Which the Br...  False          9.0
# 22756                                               Ulak  False          5.7
# 44644                         Where the Green Ants Dream  False          7.1
# 27038                                          Squatters  False          6.9
#
#       vote_count
# 13928       28.0
# 8292         1.0
# 22756        9.0
# 44644       10.0
# 27038       26.0
#
# [5 rows x 24 columns]
